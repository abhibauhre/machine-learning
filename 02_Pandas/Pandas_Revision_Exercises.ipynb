# %% [markdown]
# # Pandas Revision & Exercise Notebook
#
# Ye notebook tumhare folder ke hisaab se **Pandas Revision + Exercises** ke liye banaya gaya hai.
#
# Topics included:
# - Series
# - DataFrame
# - Conditional Filtering
# - Useful Methods
# - Missing Data
# - Groupby & MultiIndex
# - Combining DataFrames
# - Text Methods
# - Time Methods
# - Input/Output
# - Pivot Table
# - Final Practice Exercise

# %%
import pandas as pd
import numpy as np

print('Pandas Version:', pd.__version__)

# %% [markdown]
# ## **Exercise 1: Series Basics**
# 1. Ek Series banao values `[10,20,30,40]` ki.
# 2. Index ko change karo `['a','b','c','d']` se.
# 3. Series me se value access karo `'b'` index wali.

# %%
# Your code here

# %% [markdown]
# ## **Exercise 2: DataFrame Basics**
# 1. Ek DataFrame banao jisme columns ho: `Name`, `Age`, `Marks`.
# 2. 5 rows of sample data add karo.
# 3. Highest marks find karo.

# %%
# Your code here

# %% [markdown]
# ## **Exercise 3: Conditional Filtering**
# 1. DataFrame me se un rows ko filter karo jinke marks `70` se upar ho.

# %%
# Your code here

# %% [markdown]
# ## **Exercise 4: Groupby**
# Ek DataFrame banao employees data ka:
# - Name
# - Department
# - Salary
#
# Groupby karke har department ka **average salary** nikaalo.

# %%
# Your code here

# %% [markdown]
# ## **Final Project Exercise**
# 1. Ek CSV load karo (tum `world_population.csv` ya koi bhi file use kar sakte ho).
# 2. Top 10 countries by population dikhana hai.
# 3. Year wise growth calculate karna hai.
# 4. Ek simple bar chart banana hai (optional).

# %%
# Your code here
