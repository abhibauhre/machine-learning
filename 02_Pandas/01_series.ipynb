# %%
import numpy as np

# %%
import pandas as pd

# %%
my_index = ['india','usa','japan']

# %%
my_data = [1666,1777,1980]

# %%
my_ser = pd.Series(my_data,my_index)#a Series is a one-dimensional labeled array that can hold any type of data (numbers, strings, boolean, etc.).
my_ser
# Out:
# india    1666
# usa      1777
# japan    1980
# dtype: int64

# %%
my_ser[0]
# Out:
# C:\Users\abhib\AppData\Local\Temp\ipykernel_19988\3347339215.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   my_ser[0]
# np.int64(1666)

# %%
my_ser['india']
# Out:
# np.int64(1666)

# %%
fruits = {'banana':57,'apple':56,'guave':77}

# %%
pd.Series(fruits)
# Out:
# banana    57
# apple     56
# guave     77
# dtype: int64

# %%
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
q1_sales = pd.Series(q1)
q2_sales = pd.Series(q2)

# %%
q1_sales
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
q2_sales
# Out:
# Brazil    100
# China     500
# India     210
# USA       260
# dtype: int64

# %%
q1_sales * 2 #we can do opereation on pandas series
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
q1_sales + q2_sales
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
q1_sales.add(q2_sales,fill_value= 0)#fill_value is a parameter it solve the problem of NaN it add the zero to data values
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
q1_sales.dtype
# Out:
# dtype('int64')

# %%
pd.Series
# Out:
# pandas.core.series.Series
