# %%
import pandas as pd
from datetime import datetime

# %%
my_year = 2006
my_month = 11
my_day = 6
my_hour = 4
my_min = 1
my_sec = 46

# %%
my_date = datetime(my_year,my_month,my_day)

# %%
my_date
# Out:
# datetime.datetime(2006, 11, 6, 0, 0)

# %%
my_date = datetime(my_year,my_month,my_day,my_hour,my_min,my_sec)

# %%
my_date
# Out:
# datetime.datetime(2006, 11, 6, 4, 1, 46)

# %%
my_date.hour
# Out:
# 4

# %%
my_date.month
# Out:
# 11

# %%
my_date.year
# Out:
# 2006

# %%
import pandas as pd

# %%
myser = pd.Series(['Nov 3, 2000', '2000-01-01', None])

# %%
myser = pd.Series(['Nov 3, 2000', '2000-01-01', None])
result = pd.to_datetime(myser, errors='coerce')
print(result)
# Out:
# 0   2000-11-03
# 1          NaT
# 2          NaT
# dtype: datetime64[ns]

# %%
print(f"Pandas version: {pd.__version__}")
# Out:
# Pandas version: 2.3.3

# %%
obvi_euro_date = '31-12-2000'

# %%
pd.to_datetime(obvi_euro_date)
# Out:
# C:\Users\abhib\AppData\Local\Temp\ipykernel_8252\163700324.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   pd.to_datetime(obvi_euro_date)
# Timestamp('2000-12-31 00:00:00')

# %%
euro_date = '06-11-2006'
pd.to_datetime(euro_date,dayfirst = True)
# Out:
# Timestamp('2006-11-06 00:00:00')

# %%
styled_date = '06--Nov--2006'
pd.to_datetime(styled_date,format = '%d--%b--%Y')
# Out:
# Timestamp('2006-11-06 00:00:00')

# %%
strange_date = '17th of july 2006'
pd.to_datetime(strange_date)
# Out:
# Timestamp('2006-07-17 00:00:00')

# %%
sales = pd.read_csv('D:\\UNZIP-FOR-NOTEBOOKS-FINAL\\03-Pandas\\RetailSales_BeerWineLiquor.csv')

# %%
sales
# Out:
#            DATE  MRTSSM4453USN
# 0    1992-01-01           1509
# 1    1992-02-01           1541
# 2    1992-03-01           1597
# 3    1992-04-01           1675
# 4    1992-05-01           1822
# ..          ...            ...
# 335  2019-12-01           6630
# 336  2020-01-01           4388
# 337  2020-02-01           4533
# 338  2020-03-01           5562
# 339  2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
sales.iloc[0]['DATE']
# Out:
# '1992-01-01'

# %%
type(sales.iloc[0]['DATE'])
# Out:
# str

# %%
sales['DATE'] = pd.to_datetime(sales['DATE'])

# %%
sales
# Out:
#           DATE  MRTSSM4453USN
# 0   1992-01-01           1509
# 1   1992-02-01           1541
# 2   1992-03-01           1597
# 3   1992-04-01           1675
# 4   1992-05-01           1822
# ..         ...            ...
# 335 2019-12-01           6630
# 336 2020-01-01           4388
# 337 2020-02-01           4533
# 338 2020-03-01           5562
# 339 2020-04-01           5207
#
# [340 rows x 2 columns]

# %%
sales.iloc[0]['DATE']
# Out:
# Timestamp('1992-01-01 00:00:00')

# %%
type(sales.iloc[0]['DATE'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
